# %% [markdown]
# <a href="https://colab.research.google.com/github/Rumeysakeskin/Automatic-Speech-Recognition-in-Turkish/blob/main/training%26tokenizer_for_sub_word_encoding_CTC_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# If you're using Google Colab and not running locally, run this cell.
## Install dependencies
# !pip install wget
# !apt-get install sox libsndfile1 ffmpeg
# !pip install text-unidecode
# !pip install matplotlib>=3.3.2

## Install NeMo
BRANCH = 'main'
# !python -m pip install git+https://github.com/NVIDIA/NeMo.git@$BRANCH#egg=nemo_toolkit[all]
# !apt-get update && apt-get install -y libsndfile1 ffmpeg
# !pip install Cython tensorflow==2.11.0 Pygments==2.6.1 pynini==2.1.5 nemo_toolkit[all]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9674 sha256=946e5bcf69414b56563eb3dc6670266ea7a1cf070b546515a2e5587de730ba5c
#   Stored in directory: /root/.cache/pip/wheels/bd/a8/c3/3cf2c14a1837a4e04bd98631724e81f33f462d86a1d895fae0
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libsndfile1 is already the newest version (1.0.28-4ubuntu0.18.04.2).
# ffmpeg is already the newest version (7:3.4.11-0ubuntu0.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   libmagic-mgc libmagic1 libopencore-amrnb0 libopencore-amrwb0 libsox-fmt-alsa
#   libsox-fmt-base libsox3
# Suggested packages:
#   file libsox-fmt-all
# The following NEW packages will be installed:
#   libmagic-mgc libmagic1 libopencore-amrnb0 libopencore-amrwb0 libsox-fmt-alsa
#   libsox-fmt-base libsox3 sox
# 0 upgraded, 8 newly installed, 0 to remove and 21 not upgraded.
# Need to get 760 kB of archives.
# After this operation, 6,717 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libopencore-amrnb0 amd64 0.1.3-2.1 [92.0 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libopencore-amrwb0 amd64 0.1.3-2.1 [45.8 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic-mgc amd64 1:5.32-2ubuntu0.4 [184 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic1 amd64 1:5.32-2ubuntu0.4 [68.6 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libsox3 amd64 14.4.2-3ubuntu0.18.04.1 [226 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libsox-fmt-alsa amd64 14.4.2-3ubuntu0.18.04.1 [10.6 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libsox-fmt-base amd64 14.4.2-3ubuntu0.18.04.1 [32.1 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 sox amd64 14.4.2-3ubuntu0.18.04.1 [101 kB]
# Fetched 760 kB in 1s (718 kB/s)
# Selecting previously unselected package libopencore-amrnb0:amd64.
# (Reading database ... 124016 files and directories currently installed.)
# Preparing to unpack .../0-libopencore-amrnb0_0.1.3-2.1_amd64.deb ...
# Unpacking libopencore-amrnb0:amd64 (0.1.3-2.1) ...
# Selecting previously unselected package libopencore-amrwb0:amd64.
# Preparing to unpack .../1-libopencore-amrwb0_0.1.3-2.1_amd64.deb ...
# Unpacking libopencore-amrwb0:amd64 (0.1.3-2.1) ...
# Selecting previously unselected package libmagic-mgc.
# Preparing to unpack .../2-libmagic-mgc_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking libmagic-mgc (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package libmagic1:amd64.
# Preparing to unpack .../3-libmagic1_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking libmagic1:amd64 (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package libsox3:amd64.
# Preparing to unpack .../4-libsox3_14.4.2-3ubuntu0.18.04.1_amd64.deb ...
# Unpacking libsox3:amd64 (14.4.2-3ubuntu0.18.04.1) ...
# Selecting previously unselected package libsox-fmt-alsa:amd64.
# Preparing to unpack .../5-libsox-fmt-alsa_14.4.2-3ubuntu0.18.04.1_amd64.deb ...
# Unpacking libsox-fmt-alsa:amd64 (14.4.2-3ubuntu0.18.04.1) ...
# Selecting previously unselected package libsox-fmt-base:amd64.
# Preparing to unpack .../6-libsox-fmt-base_14.4.2-3ubuntu0.18.04.1_amd64.deb ...
# Unpacking libsox-fmt-base:amd64 (14.4.2-3ubuntu0.18.04.1) ...
# Selecting previously unselected package sox.
# Preparing to unpack .../7-sox_14.4.2-3ubuntu0.18.04.1_amd64.deb ...
# Unpacking sox (14.4.2-3ubuntu0.18.04.1) ...
# Setting up libmagic-mgc (1:5.32-2ubuntu0.4) ...
# Setting up libmagic1:amd64 (1:5.32-2ubuntu0.4) ...
# Setting up libopencore-amrnb0:amd64 (0.1.3-2.1) ...
# Setting up libopencore-amrwb0:amd64 (0.1.3-2.1) ...
# Setting up libsox3:amd64 (14.4.2-3ubuntu0.18.04.1) ...
# Setting up libsox-fmt-base:amd64 (14.4.2-3ubuntu0.18.04.1) ...
# Setting up libsox-fmt-alsa:amd64 (14.4.2-3ubuntu0.18.04.1) ...
# Setting up sox (14.4.2-3ubuntu0.18.04.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.6) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: text-unidecode in /usr/local/lib/python3.8/dist-packages (1.3)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting nemo_toolkit[all]
#   Cloning https://github.com/NVIDIA/NeMo.git (to revision main) to /tmp/pip-install-aukybw2i/nemo-toolkit_56238956e21c4decb669e9121e73a99d
#   Running command git clone --filter=blob:none --quiet https://github.com/NVIDIA/NeMo.git /tmp/pip-install-aukybw2i/nemo-toolkit_56238956e21c4decb669e9121e73a99d
#   Resolved https://github.com/NVIDIA/NeMo.git to commit fbdab7b710b094ef3e1e17ebec54b36f0d23b883
#   Preparing metadata (setup.py) ... done
# Collecting huggingface_hub
#   Downloading huggingface_hub-0.11.1-py3-none-any.whl (182 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.4/182.4 KB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: numba in /usr/local/lib/python3.8/dist-packages (from nemo_toolkit[all]) (0.56.4)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.8/dist-packages (from nemo_toolkit[all]) (1.21.6)
# Collecting onnx>=1.7.0
#   Downloading onnx-1.13.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 35.1 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.8/dist-packages (from nemo_toolkit[all]) (2.8.2)
# Collecting ruamel.yaml
#   Downloading ruamel.yaml-0.17.21-py3-none-any.whl (109 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.5/109.5 KB 8.4 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from nemo_toolkit[all]) (1.0.2)
# Collecting setuptools==65.5.1
#   Downloading setuptools-65.5.1-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 61.2 MB/s eta 0:00:00
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.8/dist-packages (from nemo_toolkit[all]) (2.9.1)
# Requirement already satisfied: text-unidecode in /usr/local/lib/python3.8/dist-packages (from nemo_toolkit[all]) (1.3)
# Requirement already satisfied: torch in /usr/local/lib/python3.8/dist-packages (from nemo_toolkit[all]) (1.13.0+cu116)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.8/dist-packages (from nemo_toolkit[all]) (4.64.1)
# Requirement already satisfied: wget in /usr/local/lib/python3.8/dist-packages (from nemo_toolkit[all]) (3.2)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.8/dist-packages (from nemo_toolkit[all]) (1.14.1)
# Collecting black==19.10b0
#   Downloading black-19.10b0-py36-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.5/97.5 KB 11.4 MB/s eta 0:00:00
# Collecting click==8.0.2
#   Downloading click-8.0.2-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.6/97.6 KB 11.6 MB/s eta 0:00:00
# Collecting isort[requirements]<5
#   Downloading isort-4.3.21-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 KB 5.5 MB/s eta 0:00:00
# Collecting parameterized
#   Downloading parameterized-0.8.1-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: pytest in /usr/local/lib/python3.8/dist-packages (from nemo_toolkit[all]) (3.6.4)
# Collecting pytest-runner
#   Using cached pytest_runner-6.0.0-py3-none-any.whl (7.2 kB)
# Requirement already satisfied: sphinx in /usr/local/lib/python3.8/dist-packages (from nemo_toolkit[all]) (3.5.4)
# Collecting sphinxcontrib-bibtex
#   Downloading sphinxcontrib_bibtex-2.5.0-py3-none-any.whl (39 kB)
# Collecting wandb
#   Downloading wandb-0.13.8-py2.py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 52.7 MB/s eta 0:00:00
# Requirement already satisfied: inflect in /usr/local/lib/python3.8/dist-packages (from nemo_toolkit[all]) (2.1.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.8/dist-packages (from nemo_toolkit[all]) (2022.6.2)
# Collecting hydra-core<1.3,>=1.2.0
#   Downloading hydra_core-1.2.0-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.1/151.1 KB 16.5 MB/s eta 0:00:00
# Collecting omegaconf<2.3,>=2.2
#   Downloading omegaconf-2.2.3-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.3/79.3 KB 9.0 MB/s eta 0:00:00
# Collecting pytorch-lightning>=1.8.6
#   Downloading pytorch_lightning-1.8.6-py3-none-any.whl (800 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 800.3/800.3 KB 41.6 MB/s eta 0:00:00
# Collecting pyyaml<6
#   Downloading PyYAML-5.4.1-cp38-cp38-manylinux1_x86_64.whl (662 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 662.4/662.4 KB 45.3 MB/s eta 0:00:00
# Collecting torchmetrics<=0.10.3,>=0.4.1rc0
#   Downloading torchmetrics-0.10.3-py3-none-any.whl (529 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 529.7/529.7 KB 35.5 MB/s eta 0:00:00
# Collecting transformers<=4.21.2,>=4.0.1
#   Downloading transformers-4.21.2-py3-none-any.whl (4.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 68.2 MB/s eta 0:00:00
# Collecting webdataset<=0.1.62,>=0.1.48
#   Downloading webdataset-0.1.62-py3-none-any.whl (32 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from nemo_toolkit[all]) (1.3.5)
# Collecting sacremoses>=0.0.43
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 880.6/880.6 KB 52.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting sentencepiece<1.0.0
#   Downloading sentencepiece-0.1.97-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 61.6 MB/s eta 0:00:00
# Collecting youtokentome>=1.0.5
#   Downloading youtokentome-1.0.6-cp38-cp38-manylinux2010_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 52.9 MB/s eta 0:00:00
# Collecting braceexpand
#   Downloading braceexpand-0.1.7-py2.py3-none-any.whl (5.9 kB)
# Requirement already satisfied: editdistance in /usr/local/lib/python3.8/dist-packages (from nemo_toolkit[all]) (0.5.3)
# Collecting g2p_en
#   Downloading g2p_en-2.1.0-py3-none-any.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 76.7 MB/s eta 0:00:00
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.8/dist-packages (from nemo_toolkit[all]) (7.7.1)
# Collecting jiwer
#   Downloading jiwer-2.5.1-py3-none-any.whl (15 kB)
# Collecting kaldi-python-io
#   Downloading kaldi-python-io-1.2.2.tar.gz (8.8 kB)
#   Preparing metadata (setup.py) ... done
# Collecting kaldiio
#   Downloading kaldiio-2.17.2.tar.gz (24 kB)
#   Preparing metadata (setup.py) ... done
# Collecting librosa>=0.9.0
#   Downloading librosa-0.9.2-py3-none-any.whl (214 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.3/214.3 KB 22.3 MB/s eta 0:00:00
# Requirement already satisfied: marshmallow in /usr/local/lib/python3.8/dist-packages (from nemo_toolkit[all]) (3.19.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.8/dist-packages (from nemo_toolkit[all]) (3.2.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from nemo_toolkit[all]) (21.3)
# Collecting pyannote.core
#   Downloading pyannote.core-5.0.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.5/58.5 KB 6.2 MB/s eta 0:00:00
# Collecting pyannote.metrics
#   Downloading pyannote.metrics-3.2.1-py3-none-any.whl (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.4/51.4 KB 5.2 MB/s eta 0:00:00
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.8/dist-packages (from nemo_toolkit[all]) (1.7.3)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.8/dist-packages (from nemo_toolkit[all]) (0.11.0)
# Collecting sox
#   Downloading sox-1.4.1-py2.py3-none-any.whl (39 kB)
# Collecting texterrors
#   Downloading texterrors-0.4.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 59.1 MB/s eta 0:00:00
# Collecting boto3
#   Downloading boto3-1.26.47-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.7/132.7 KB 14.6 MB/s eta 0:00:00
# Collecting einops
#   Downloading einops-0.6.0-py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.6/41.6 KB 4.5 MB/s eta 0:00:00
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.7.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 71.1 MB/s eta 0:00:00
# Collecting fasttext
#   Downloading fasttext-0.9.2.tar.gz (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.8/68.8 KB 8.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting flask_restful
#   Downloading Flask_RESTful-0.3.9-py2.py3-none-any.whl (25 kB)
# Collecting ftfy
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 KB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: gdown in /usr/local/lib/python3.8/dist-packages (from nemo_toolkit[all]) (4.4.0)
# Collecting gradio==3.4.0
#   Downloading gradio-3.4.0-py3-none-any.whl (5.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 84.2 MB/s eta 0:00:00
# Requirement already satisfied: h5py in /usr/local/lib/python3.8/dist-packages (from nemo_toolkit[all]) (3.1.0)
# Collecting ijson
#   Downloading ijson-3.2.0.post0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.8/114.8 KB 13.1 MB/s eta 0:00:00
# Requirement already satisfied: jieba in /usr/local/lib/python3.8/dist-packages (from nemo_toolkit[all]) (0.42.1)
# Collecting matplotlib
#   Downloading matplotlib-3.6.2-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (9.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 88.8 MB/s eta 0:00:00
# Requirement already satisfied: nltk>=3.6.5 in /usr/local/lib/python3.8/dist-packages (from nemo_toolkit[all]) (3.7)
# Collecting opencc
#   Downloading OpenCC-1.1.6-cp38-cp38-manylinux1_x86_64.whl (778 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 778.2/778.2 KB 35.1 MB/s eta 0:00:00
# Collecting pangu
#   Downloading pangu-4.0.6.1-py3-none-any.whl (6.4 kB)
# Collecting rapidfuzz
#   Downloading rapidfuzz-2.13.7-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 74.7 MB/s eta 0:00:00
# Collecting sacrebleu[ja]
#   Downloading sacrebleu-2.3.1-py3-none-any.whl (118 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.9/118.9 KB 572.0 kB/s eta 0:00:00
# Collecting sentence_transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 KB 10.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting attrdict
#   Downloading attrdict-2.0.1-py2.py3-none-any.whl (9.9 kB)
# Collecting pypinyin
#   Downloading pypinyin-0.47.1-py2.py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 67.7 MB/s eta 0:00:00
# Collecting pypinyin-dict
#   Downloading pypinyin_dict-0.4.0-py2.py3-none-any.whl (9.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 80.0 MB/s eta 0:00:00
# Collecting progress>=1.5
#   Downloading progress-1.6.tar.gz (7.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tabulate>=0.8.7 in /usr/local/lib/python3.8/dist-packages (from nemo_toolkit[all]) (0.8.10)
# Collecting textdistance>=4.1.5
#   Downloading textdistance-4.5.0-py3-none-any.whl (31 kB)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.8/dist-packages (from black==19.10b0->nemo_toolkit[all]) (1.4.4)
# Requirement already satisfied: attrs>=18.1.0 in /usr/local/lib/python3.8/dist-packages (from black==19.10b0->nemo_toolkit[all]) (22.2.0)
# Collecting pathspec<1,>=0.6
#   Downloading pathspec-0.10.3-py3-none-any.whl (29 kB)
# Requirement already satisfied: toml>=0.9.4 in /usr/local/lib/python3.8/dist-packages (from black==19.10b0->nemo_toolkit[all]) (0.10.2)
# Collecting typed-ast>=1.4.0
#   Downloading typed_ast-1.5.4-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (897 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.2/897.2 KB 54.3 MB/s eta 0:00:00
# Collecting httpx
#   Downloading httpx-0.23.3-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 KB 7.7 MB/s eta 0:00:00
# Collecting fastapi
#   Downloading fastapi-0.89.1-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 KB 7.1 MB/s eta 0:00:00
# Collecting websockets
#   Downloading websockets-10.4-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.0/107.0 KB 11.6 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.8/dist-packages (from gradio==3.4.0->nemo_toolkit[all]) (3.8.3)
# Collecting uvicorn
#   Downloading uvicorn-0.20.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 KB 6.8 MB/s eta 0:00:00
# Collecting ffmpy
#   Downloading ffmpy-0.3.0.tar.gz (4.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from gradio==3.4.0->nemo_toolkit[all]) (2.25.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.8/dist-packages (from gradio==3.4.0->nemo_toolkit[all]) (2022.11.0)
# Collecting pycryptodome
#   Downloading pycryptodome-3.16.0-cp35-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 75.8 MB/s eta 0:00:00
# Collecting markdown-it-py[linkify,plugins]
#   Downloading markdown_it_py-2.1.0-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 KB 10.6 MB/s eta 0:00:00
# Collecting paramiko
#   Downloading paramiko-2.12.0-py2.py3-none-any.whl (213 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.1/213.1 KB 24.4 MB/s eta 0:00:00
# Collecting orjson
#   Downloading orjson-3.8.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (270 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.5/270.5 KB 28.8 MB/s eta 0:00:00
# Requirement already satisfied: pillow in /usr/local/lib/python3.8/dist-packages (from gradio==3.4.0->nemo_toolkit[all]) (7.1.2)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.8/dist-packages (from gradio==3.4.0->nemo_toolkit[all]) (1.10.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from gradio==3.4.0->nemo_toolkit[all]) (2.11.3)
# Collecting python-multipart
#   Downloading python-multipart-0.0.5.tar.gz (32 kB)
#   Preparing metadata (setup.py) ... done
# Collecting h11<0.13,>=0.11
#   Downloading h11-0.12.0-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.9/54.9 KB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.8/dist-packages (from hydra-core<1.3,>=1.2.0->nemo_toolkit[all]) (5.10.2)
# Collecting antlr4-python3-runtime==4.9.*
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 KB 13.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pip-api
#   Downloading pip_api-0.0.30-py3-none-any.whl (111 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.6/111.6 KB 12.8 MB/s eta 0:00:00
# Collecting pipreqs
#   Downloading pipreqs-0.4.11-py2.py3-none-any.whl (32 kB)
# Collecting levenshtein==0.20.2
#   Downloading Levenshtein-0.20.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 63.9 MB/s eta 0:00:00
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.8/dist-packages (from librosa>=0.9.0->nemo_toolkit[all]) (3.0.0)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.8/dist-packages (from librosa>=0.9.0->nemo_toolkit[all]) (1.2.0)
# Requirement already satisfied: resampy>=0.2.2 in /usr/local/lib/python3.8/dist-packages (from librosa>=0.9.0->nemo_toolkit[all]) (0.4.2)
# Requirement already satisfied: decorator>=4.0.10 in /usr/local/lib/python3.8/dist-packages (from librosa>=0.9.0->nemo_toolkit[all]) (4.4.2)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.8/dist-packages (from librosa>=0.9.0->nemo_toolkit[all]) (1.6.0)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.0.6-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.0/296.0 KB 28.8 MB/s eta 0:00:00
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib->nemo_toolkit[all]) (0.11.0)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.38.0-py3-none-any.whl (965 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 965.4/965.4 KB 57.7 MB/s eta 0:00:00
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->nemo_toolkit[all]) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->nemo_toolkit[all]) (3.0.9)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.8/dist-packages (from numba->nemo_toolkit[all]) (6.0.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.8/dist-packages (from numba->nemo_toolkit[all]) (0.39.1)
# Collecting protobuf<4,>=3.20.2
#   Downloading protobuf-3.20.3-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 59.2 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /usr/local/lib/python3.8/dist-packages (from onnx>=1.7.0->nemo_toolkit[all]) (4.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil->nemo_toolkit[all]) (1.15.0)
# Collecting lightning-utilities!=0.4.0,>=0.3.0
#   Downloading lightning_utilities-0.5.0-py3-none-any.whl (18 kB)
# Collecting tensorboardX>=2.2
#   Downloading tensorboardX-2.5.1-py2.py3-none-any.whl (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.4/125.4 KB 15.4 MB/s eta 0:00:00
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->nemo_toolkit[all]) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.8/dist-packages (from soundfile->nemo_toolkit[all]) (1.15.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers<=4.21.2,>=4.0.1->nemo_toolkit[all]) (3.9.0)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 79.4 MB/s eta 0:00:00
# Collecting s3transfer<0.7.0,>=0.6.0
#   Downloading s3transfer-0.6.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.6/79.6 KB 8.0 MB/s eta 0:00:00
# Collecting botocore<1.30.0,>=1.29.47
#   Downloading botocore-1.29.47-py3-none-any.whl (10.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 80.1 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting pybind11>=2.2
#   Using cached pybind11-2.10.3-py3-none-any.whl (222 kB)
# Requirement already satisfied: pytz in /usr/local/lib/python3.8/dist-packages (from flask_restful->nemo_toolkit[all]) (2022.7)
# Requirement already satisfied: Flask>=0.8 in /usr/local/lib/python3.8/dist-packages (from flask_restful->nemo_toolkit[all]) (1.1.4)
# Collecting aniso8601>=0.82
#   Downloading aniso8601-9.0.1-py2.py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 KB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.8/dist-packages (from ftfy->nemo_toolkit[all]) (0.2.5)
# Collecting distance>=0.1.3
#   Downloading Distance-0.1.3.tar.gz (180 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.3/180.3 KB 16.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.8/dist-packages (from gdown->nemo_toolkit[all]) (4.6.3)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets->nemo_toolkit[all]) (7.9.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets->nemo_toolkit[all]) (3.0.5)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.8/dist-packages (from ipywidgets->nemo_toolkit[all]) (5.3.4)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.8/dist-packages (from ipywidgets->nemo_toolkit[all]) (5.7.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets->nemo_toolkit[all]) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets->nemo_toolkit[all]) (3.6.1)
# Requirement already satisfied: sortedcontainers>=2.0.4 in /usr/local/lib/python3.8/dist-packages (from pyannote.core->nemo_toolkit[all]) (2.4.0)
# Collecting docopt>=0.6.2
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: sympy>=1.1 in /usr/local/lib/python3.8/dist-packages (from pyannote.metrics->nemo_toolkit[all]) (1.7.1)
# Collecting pyannote.database>=4.0.1
#   Downloading pyannote.database-4.1.3-py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.6/41.6 KB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.8/dist-packages (from pytest->nemo_toolkit[all]) (0.7.1)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.8/dist-packages (from pytest->nemo_toolkit[all]) (9.0.0)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.8/dist-packages (from pytest->nemo_toolkit[all]) (1.11.0)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.8/dist-packages (from pytest->nemo_toolkit[all]) (1.4.1)
# Collecting ruamel.yaml.clib>=0.2.6
#   Downloading ruamel.yaml.clib-0.2.7-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (555 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 555.3/555.3 KB 42.7 MB/s eta 0:00:00
# Collecting portalocker
#   Downloading portalocker-2.6.0-py2.py3-none-any.whl (15 kB)
# Collecting colorama
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.8/dist-packages (from sacrebleu[ja]->nemo_toolkit[all]) (4.9.2)
# Collecting ipadic<2.0,>=1.0
#   Downloading ipadic-1.0.0.tar.gz (13.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 78.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting mecab-python3==1.0.5
#   Downloading mecab_python3-1.0.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (577 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 577.3/577.3 KB 35.3 MB/s eta 0:00:00
# Requirement already satisfied: torchvision in /usr/local/lib/python3.8/dist-packages (from sentence_transformers->nemo_toolkit[all]) (0.14.0+cu116)
# Requirement already satisfied: sphinxcontrib-htmlhelp in /usr/local/lib/python3.8/dist-packages (from sphinx->nemo_toolkit[all]) (2.0.0)
# Requirement already satisfied: sphinxcontrib-qthelp in /usr/local/lib/python3.8/dist-packages (from sphinx->nemo_toolkit[all]) (1.0.3)
# Requirement already satisfied: Pygments>=2.0 in /usr/local/lib/python3.8/dist-packages (from sphinx->nemo_toolkit[all]) (2.6.1)
# Requirement already satisfied: sphinxcontrib-jsmath in /usr/local/lib/python3.8/dist-packages (from sphinx->nemo_toolkit[all]) (1.0.1)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /usr/local/lib/python3.8/dist-packages (from sphinx->nemo_toolkit[all]) (0.7.12)
# Requirement already satisfied: sphinxcontrib-serializinghtml in /usr/local/lib/python3.8/dist-packages (from sphinx->nemo_toolkit[all]) (1.1.5)
# Requirement already satisfied: sphinxcontrib-applehelp in /usr/local/lib/python3.8/dist-packages (from sphinx->nemo_toolkit[all]) (1.0.2)
# Requirement already satisfied: docutils<0.17,>=0.12 in /usr/local/lib/python3.8/dist-packages (from sphinx->nemo_toolkit[all]) (0.16)
# Requirement already satisfied: snowballstemmer>=1.1 in /usr/local/lib/python3.8/dist-packages (from sphinx->nemo_toolkit[all]) (2.2.0)
# Requirement already satisfied: imagesize in /usr/local/lib/python3.8/dist-packages (from sphinx->nemo_toolkit[all]) (1.4.1)
# Requirement already satisfied: babel>=1.3 in /usr/local/lib/python3.8/dist-packages (from sphinx->nemo_toolkit[all]) (2.11.0)
# Requirement already satisfied: sphinxcontrib-devhelp in /usr/local/lib/python3.8/dist-packages (from sphinx->nemo_toolkit[all]) (1.0.2)
# Collecting pybtex>=0.24
#   Downloading pybtex-0.24.0-py2.py3-none-any.whl (561 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 561.4/561.4 KB 36.2 MB/s eta 0:00:00
# Collecting pybtex-docutils>=1.0.0
#   Downloading pybtex_docutils-1.0.2-py3-none-any.whl (6.3 kB)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard->nemo_toolkit[all]) (3.4.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard->nemo_toolkit[all]) (1.51.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard->nemo_toolkit[all]) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard->nemo_toolkit[all]) (0.4.6)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard->nemo_toolkit[all]) (1.0.1)
# Collecting tensorboard
#   Downloading tensorboard-2.11.0-py3-none-any.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 79.8 MB/s eta 0:00:00
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard->nemo_toolkit[all]) (1.8.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.8/dist-packages (from tensorboard->nemo_toolkit[all]) (1.3.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard->nemo_toolkit[all]) (2.15.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.8/dist-packages (from tensorboard->nemo_toolkit[all]) (0.38.4)
# Collecting loguru
#   Downloading loguru-0.6.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 KB 6.7 MB/s eta 0:00:00
# Requirement already satisfied: termcolor in /usr/local/lib/python3.8/dist-packages (from texterrors->nemo_toolkit[all]) (2.2.0)
# Collecting plac
#   Downloading plac-1.3.5-py2.py3-none-any.whl (22 kB)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.30-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.0/184.0 KB 19.3 MB/s eta 0:00:00
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.8/dist-packages (from wandb->nemo_toolkit[all]) (5.4.8)
# Collecting setproctitle
#   Downloading setproctitle-1.3.2-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (31 kB)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.12.1-py2.py3-none-any.whl (174 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.3/174.3 KB 19.1 MB/s eta 0:00:00
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Collecting urllib3<1.27,>=1.25.4
#   Downloading urllib3-1.26.13-py2.py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 KB 15.9 MB/s eta 0:00:00
# Requirement already satisfied: pycparser in /usr/local/lib/python3.8/dist-packages (from cffi>=1.0->soundfile->nemo_toolkit[all]) (2.21)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.8/dist-packages (from Flask>=0.8->flask_restful->nemo_toolkit[all]) (1.1.0)
# Collecting Flask>=0.8
#   Downloading Flask-2.2.2-py3-none-any.whl (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.5/101.5 KB 12.3 MB/s eta 0:00:00
# Collecting werkzeug>=1.0.1
#   Downloading Werkzeug-2.2.2-py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.7/232.7 KB 21.8 MB/s eta 0:00:00
# Collecting itsdangerous>=2.0
#   Downloading itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Collecting jinja2
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.1/133.1 KB 16.0 MB/s eta 0:00:00
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/dist-packages (from aiohttp->gradio==3.4.0->nemo_toolkit[all]) (4.0.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->gradio==3.4.0->nemo_toolkit[all]) (2.1.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp->gradio==3.4.0->nemo_toolkit[all]) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->gradio==3.4.0->nemo_toolkit[all]) (1.8.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from aiohttp->gradio==3.4.0->nemo_toolkit[all]) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from aiohttp->gradio==3.4.0->nemo_toolkit[all]) (1.3.1)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 8.1 MB/s eta 0:00:00
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard->nemo_toolkit[all]) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard->nemo_toolkit[all]) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard->nemo_toolkit[all]) (5.2.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->nemo_toolkit[all]) (1.3.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata->numba->nemo_toolkit[all]) (3.11.0)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.8/dist-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[all]) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.8/dist-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[all]) (6.0.4)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (4.8.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (2.0.10)
# Requirement already satisfied: backcall in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (0.2.0)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 68.1 MB/s eta 0:00:00
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (0.7.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.8/dist-packages (from jinja2->gradio==3.4.0->nemo_toolkit[all]) (2.0.1)
# Requirement already satisfied: typer[all]>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[all]) (0.7.0)
# Collecting latexcodec>=1.0.4
#   Downloading latexcodec-2.0.1-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->gradio==3.4.0->nemo_toolkit[all]) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->gradio==3.4.0->nemo_toolkit[all]) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->gradio==3.4.0->nemo_toolkit[all]) (4.0.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.8/dist-packages (from sympy>=1.1->pyannote.metrics->nemo_toolkit[all]) (1.2.1)
# Collecting tensorboardX>=2.2
#   Downloading tensorboardX-2.5-py2.py3-none-any.whl (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.3/125.3 KB 5.6 MB/s eta 0:00:00
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.1.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.8/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (5.7.16)
# Collecting starlette==0.22.0
#   Downloading starlette-0.22.0-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.3/64.3 KB 8.0 MB/s eta 0:00:00
# Collecting anyio<5,>=3.4.0
#   Downloading anyio-3.6.2-py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 KB 8.4 MB/s eta 0:00:00
# Collecting httpcore<0.17.0,>=0.15.0
#   Downloading httpcore-0.16.3-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.6/69.6 KB 7.2 MB/s eta 0:00:00
# Collecting rfc3986[idna2008]<2,>=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Collecting sniffio
#   Downloading sniffio-1.3.0-py3-none-any.whl (10 kB)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Collecting mdit-py-plugins
#   Downloading mdit_py_plugins-0.3.3-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 KB 6.4 MB/s eta 0:00:00
# Collecting linkify-it-py~=1.0
#   Downloading linkify_it_py-1.0.3-py3-none-any.whl (19 kB)
# Collecting pynacl>=1.0.1
#   Downloading PyNaCl-1.5.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (856 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 856.7/856.7 KB 50.0 MB/s eta 0:00:00
# Collecting bcrypt>=3.1.3
#   Downloading bcrypt-4.0.1-cp36-abi3-manylinux_2_24_x86_64.whl (593 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 593.2/593.2 KB 48.4 MB/s eta 0:00:00
# Collecting cryptography>=2.5
#   Downloading cryptography-39.0.0-cp36-abi3-manylinux_2_24_x86_64.whl (4.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 87.6 MB/s eta 0:00:00
# Requirement already satisfied: pip in /usr/local/lib/python3.8/dist-packages (from pip-api->isort[requirements]<5->nemo_toolkit[all]) (22.0.4)
# Collecting yarg
#   Downloading yarg-0.1.9-py2.py3-none-any.whl (19 kB)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.8/dist-packages (from requests->gradio==3.4.0->nemo_toolkit[all]) (1.7.1)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Collecting httpcore<0.17.0,>=0.15.0
#   Downloading httpcore-0.16.2-py3-none-any.whl (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.0/69.0 KB 8.0 MB/s eta 0:00:00
#   Downloading httpcore-0.16.1-py3-none-any.whl (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.7/68.7 KB 8.6 MB/s eta 0:00:00
#   Downloading httpcore-0.16.0-py3-none-any.whl (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.7/68.7 KB 8.4 MB/s eta 0:00:00
#   Downloading httpcore-0.15.0-py3-none-any.whl (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.4/68.4 KB 7.6 MB/s eta 0:00:00
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.8/dist-packages (from jedi>=0.10->ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (0.8.3)
# Collecting uc-micro-py
#   Downloading uc_micro_py-1.0.1-py3-none-any.whl (6.2 kB)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (5.7.1)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.13.3)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (23.2.1)
# Requirement already satisfied: nbconvert<6.0 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (5.6.1)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (1.8.0)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.15.0)
# Requirement already satisfied: jupyter-core>=4.4.0 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (5.1.2)
# Collecting jinja2
#   Downloading Jinja2-3.0.0-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 KB 15.4 MB/s eta 0:00:00
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->nemo_toolkit[all]) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->nemo_toolkit[all]) (3.2.2)
# Collecting shellingham<2.0.0,>=1.3.0
#   Downloading shellingham-1.5.0.post1-py2.py3-none-any.whl (9.4 kB)
# Collecting rich<13.0.0,>=10.11.0
#   Downloading rich-12.6.0-py3-none-any.whl (237 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 237.5/237.5 KB 26.6 MB/s eta 0:00:00
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.8/dist-packages (from pexpect->ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (0.7.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.8/dist-packages (from jupyter-core>=4.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (2.6.2)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (1.5.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.4)
# Requirement already satisfied: bleach in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (5.0.1)
# Requirement already satisfied: testpath in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.6.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.8/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (4.3.3)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.8/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (2.16.2)
# Collecting commonmark<0.10.0,>=0.9.0
#   Downloading commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.1/51.1 KB 6.4 MB/s eta 0:00:00
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.19.3)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.8/dist-packages (from bleach->nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.5.1)
# Building wheels for collected packages: antlr4-python3-runtime, progress, sacremoses, fasttext, kaldi-python-io, kaldiio, nemo_toolkit, sentence_transformers, distance, docopt, ipadic, ffmpy, pathtools, python-multipart
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144575 sha256=920faaa2141f55ad560351d938d89519d2bc40a5edf35233116e02d0efc1b862
#   Stored in directory: /root/.cache/pip/wheels/b1/a3/c2/6df046c09459b73cc9bb6c4401b0be6c47048baf9a1617c485
#   Building wheel for progress (setup.py) ... done
#   Created wheel for progress: filename=progress-1.6-py3-none-any.whl size=9630 sha256=1bd60eb741cdcbf1355504eea94b419254eef205b873e9cd2c1ad2af8874f053
#   Stored in directory: /root/.cache/pip/wheels/bb/01/5a/c916509df9b12c6465864251dbe826def8e31a16fa7da54f08
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895260 sha256=5e841c39e360c2bd624edd7e0f9ef3032e2dd47d68f20378d6bd36dea5cf0ce2
#   Stored in directory: /root/.cache/pip/wheels/82/ab/9b/c15899bf659ba74f623ac776e861cf2eb8608c1825ddec66a4
#   Building wheel for fasttext (setup.py) ... done
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp38-cp38-linux_x86_64.whl size=3130394 sha256=7274d81b64b01290f4e9a1c6d04c23d37f453fb964d383e474e8f77bb423a3c3
#   Stored in directory: /root/.cache/pip/wheels/93/61/2a/c54711a91c418ba06ba195b1d78ff24fcaad8592f2a694ac94
#   Building wheel for kaldi-python-io (setup.py) ... done
#   Created wheel for kaldi-python-io: filename=kaldi_python_io-1.2.2-py3-none-any.whl size=8970 sha256=7ab093fb99ffb0cd93c72fe01dee16faf5eea5f08400077a5892849bd11c861a
#   Stored in directory: /root/.cache/pip/wheels/8c/da/46/4afb7e26376c33af41c3ec388d5b63d34d186f6df1545cac30
#   Building wheel for kaldiio (setup.py) ... done
#   Created wheel for kaldiio: filename=kaldiio-2.17.2-py3-none-any.whl size=24471 sha256=acfd67b09dfd2c0084eccd2182799656914ccc0cde965e250bd0bdc773474495
#   Stored in directory: /root/.cache/pip/wheels/49/b3/00/af2103b510836161326bb51e27795407b07fda6969d0ae5967
#   Building wheel for nemo_toolkit (setup.py) ... done
#   Created wheel for nemo_toolkit: filename=nemo_toolkit-1.15.0rc0-py3-none-any.whl size=4347152 sha256=5ef58ed6107fb8ca6e1f8eab37e0163fde2ce09e6a0b7876f23d0a762b57d826
#   Stored in directory: /tmp/pip-ephem-wheel-cache-cfll250p/wheels/76/8c/14/f1ad178881c7340cf8e629686593904531249cf8b2de155d8c
#   Building wheel for sentence_transformers (setup.py) ... done
#   Created wheel for sentence_transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125938 sha256=b4f6a88cf792783070987934ac84b8b80d7a2ab3506c4844391c75697c856df2
#   Stored in directory: /root/.cache/pip/wheels/5e/6f/8c/d88aec621f3f542d26fac0342bef5e693335d125f4e54aeffe
#   Building wheel for distance (setup.py) ... done
# ...
# Requirement already satisfied: imagesize in /usr/local/lib/python3.8/dist-packages (from sphinx->nemo_toolkit[all]) (1.4.1)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /usr/local/lib/python3.8/dist-packages (from sphinx->nemo_toolkit[all]) (0.7.12)
# Requirement already satisfied: sphinxcontrib-serializinghtml in /usr/local/lib/python3.8/dist-packages (from sphinx->nemo_toolkit[all]) (1.1.5)
# Requirement already satisfied: sphinxcontrib-applehelp in /usr/local/lib/python3.8/dist-packages (from sphinx->nemo_toolkit[all]) (1.0.2)
# Requirement already satisfied: sphinxcontrib-qthelp in /usr/local/lib/python3.8/dist-packages (from sphinx->nemo_toolkit[all]) (1.0.3)
# Requirement already satisfied: sphinxcontrib-htmlhelp in /usr/local/lib/python3.8/dist-packages (from sphinx->nemo_toolkit[all]) (2.0.0)
# Requirement already satisfied: snowballstemmer>=1.1 in /usr/local/lib/python3.8/dist-packages (from sphinx->nemo_toolkit[all]) (2.2.0)
# Requirement already satisfied: sphinxcontrib-devhelp in /usr/local/lib/python3.8/dist-packages (from sphinx->nemo_toolkit[all]) (1.0.2)
# Requirement already satisfied: babel>=1.3 in /usr/local/lib/python3.8/dist-packages (from sphinx->nemo_toolkit[all]) (2.11.0)
# Requirement already satisfied: docutils<0.17,>=0.12 in /usr/local/lib/python3.8/dist-packages (from sphinx->nemo_toolkit[all]) (0.16)
# Requirement already satisfied: sphinxcontrib-jsmath in /usr/local/lib/python3.8/dist-packages (from sphinx->nemo_toolkit[all]) (1.0.1)
# Requirement already satisfied: pybtex>=0.24 in /usr/local/lib/python3.8/dist-packages (from sphinxcontrib-bibtex->nemo_toolkit[all]) (0.24.0)
# Requirement already satisfied: pybtex-docutils>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from sphinxcontrib-bibtex->nemo_toolkit[all]) (1.0.2)
# Requirement already satisfied: loguru in /usr/local/lib/python3.8/dist-packages (from texterrors->nemo_toolkit[all]) (0.6.0)
# Requirement already satisfied: plac in /usr/local/lib/python3.8/dist-packages (from texterrors->nemo_toolkit[all]) (1.3.5)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from wandb->nemo_toolkit[all]) (1.12.1)
# Requirement already satisfied: GitPython>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from wandb->nemo_toolkit[all]) (3.1.30)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.8/dist-packages (from wandb->nemo_toolkit[all]) (5.4.8)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.8/dist-packages (from wandb->nemo_toolkit[all]) (1.3.2)
# Requirement already satisfied: pathtools in /usr/local/lib/python3.8/dist-packages (from wandb->nemo_toolkit[all]) (0.1.2)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.8/dist-packages (from wandb->nemo_toolkit[all]) (0.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /usr/local/lib/python3.8/dist-packages (from botocore<1.30.0,>=1.29.47->boto3->nemo_toolkit[all]) (1.26.13)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.8/dist-packages (from cffi>=1.0->soundfile->nemo_toolkit[all]) (2.21)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.8/dist-packages (from Flask>=0.8->flask-restful->nemo_toolkit[all]) (2.1.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp->gradio==3.4.0->nemo_toolkit[all]) (6.0.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from aiohttp->gradio==3.4.0->nemo_toolkit[all]) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/dist-packages (from aiohttp->gradio==3.4.0->nemo_toolkit[all]) (4.0.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->gradio==3.4.0->nemo_toolkit[all]) (2.1.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from aiohttp->gradio==3.4.0->nemo_toolkit[all]) (1.3.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->gradio==3.4.0->nemo_toolkit[all]) (1.8.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.8/dist-packages (from GitPython>=1.0.0->wandb->nemo_toolkit[all]) (4.0.10)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow==2.11.0) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow==2.11.0) (5.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow==2.11.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow==2.11.0) (1.3.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata->numba->nemo_toolkit[all]) (3.11.0)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.8/dist-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[all]) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.8/dist-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[all]) (6.0.4)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (0.7.5)
# Requirement already satisfied: backcall in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (0.2.0)
# Requirement already satisfied: jedi>=0.10 in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (0.18.2)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (4.8.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (2.0.10)
# Requirement already satisfied: MarkupSafe>=2.0.0rc2 in /usr/local/lib/python3.8/dist-packages (from jinja2->gradio==3.4.0->nemo_toolkit[all]) (2.1.1)
# Requirement already satisfied: typer[all]>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[all]) (0.7.0)
# Requirement already satisfied: latexcodec>=1.0.4 in /usr/local/lib/python3.8/dist-packages (from pybtex>=0.24->sphinxcontrib-bibtex->nemo_toolkit[all]) (2.0.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->gradio==3.4.0->nemo_toolkit[all]) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->gradio==3.4.0->nemo_toolkit[all]) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->gradio==3.4.0->nemo_toolkit[all]) (2.10)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.8/dist-packages (from sympy>=1.1->pyannote.metrics->nemo_toolkit[all]) (1.2.1)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.8/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (5.7.16)
# Requirement already satisfied: starlette==0.22.0 in /usr/local/lib/python3.8/dist-packages (from fastapi->gradio==3.4.0->nemo_toolkit[all]) (0.22.0)
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/lib/python3.8/dist-packages (from starlette==0.22.0->fastapi->gradio==3.4.0->nemo_toolkit[all]) (3.6.2)
# Requirement already satisfied: httpcore<0.17.0,>=0.15.0 in /usr/local/lib/python3.8/dist-packages (from httpx->gradio==3.4.0->nemo_toolkit[all]) (0.15.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.8/dist-packages (from httpx->gradio==3.4.0->nemo_toolkit[all]) (1.3.0)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in /usr/local/lib/python3.8/dist-packages (from httpx->gradio==3.4.0->nemo_toolkit[all]) (1.5.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.8/dist-packages (from markdown-it-py[linkify,plugins]->gradio==3.4.0->nemo_toolkit[all]) (0.1.2)
# Requirement already satisfied: mdit-py-plugins in /usr/local/lib/python3.8/dist-packages (from markdown-it-py[linkify,plugins]->gradio==3.4.0->nemo_toolkit[all]) (0.3.3)
# Requirement already satisfied: linkify-it-py~=1.0 in /usr/local/lib/python3.8/dist-packages (from markdown-it-py[linkify,plugins]->gradio==3.4.0->nemo_toolkit[all]) (1.0.3)
# Requirement already satisfied: cryptography>=2.5 in /usr/local/lib/python3.8/dist-packages (from paramiko->gradio==3.4.0->nemo_toolkit[all]) (39.0.0)
# Requirement already satisfied: pynacl>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from paramiko->gradio==3.4.0->nemo_toolkit[all]) (1.5.0)
# Requirement already satisfied: bcrypt>=3.1.3 in /usr/local/lib/python3.8/dist-packages (from paramiko->gradio==3.4.0->nemo_toolkit[all]) (4.0.1)
# Requirement already satisfied: pip in /usr/local/lib/python3.8/dist-packages (from pip-api->isort[requirements]<5->nemo_toolkit[all]) (22.0.4)
# Requirement already satisfied: yarg in /usr/local/lib/python3.8/dist-packages (from pipreqs->isort[requirements]<5->nemo_toolkit[all]) (0.1.9)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.8/dist-packages (from requests->gradio==3.4.0->nemo_toolkit[all]) (1.7.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.8/dist-packages (from gitdb<5,>=4.0.1->GitPython>=1.0.0->wandb->nemo_toolkit[all]) (5.0.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.8/dist-packages (from jedi>=0.10->ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (0.8.3)
# Requirement already satisfied: uc-micro-py in /usr/local/lib/python3.8/dist-packages (from linkify-it-py~=1.0->markdown-it-py[linkify,plugins]->gradio==3.4.0->nemo_toolkit[all]) (1.0.1)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (23.2.1)
# Requirement already satisfied: jupyter-core>=4.4.0 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (5.1.2)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.15.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (5.7.1)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.13.3)
# Requirement already satisfied: nbconvert<6.0 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (5.6.1)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (1.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow==2.11.0) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow==2.11.0) (3.2.2)
# Requirement already satisfied: shellingham<2.0.0,>=1.3.0 in /usr/local/lib/python3.8/dist-packages (from typer[all]>=0.2.1->pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[all]) (1.5.0.post1)
# Requirement already satisfied: rich<13.0.0,>=10.11.0 in /usr/local/lib/python3.8/dist-packages (from typer[all]>=0.2.1->pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[all]) (12.6.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.8/dist-packages (from pexpect->ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (0.7.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.8/dist-packages (from jupyter-core>=4.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (2.6.2)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (1.5.0)
# Requirement already satisfied: testpath in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.6.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.8.4)
# Requirement already satisfied: bleach in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (5.0.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.4)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.8/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (4.3.3)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.8/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (2.16.2)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /usr/local/lib/python3.8/dist-packages (from rich<13.0.0,>=10.11.0->typer[all]>=0.2.1->pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[all]) (0.9.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.19.3)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.8/dist-packages (from bleach->nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.5.1)
# Installing collected packages: flatbuffers, tensorflow-estimator, pynini, protobuf, keras, onnx, tensorflow
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 1.12
#     Uninstalling flatbuffers-1.12:
#       Successfully uninstalled flatbuffers-1.12
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.9.0
#     Uninstalling tensorflow-estimator-2.9.0:
#       Successfully uninstalled tensorflow-estimator-2.9.0
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: keras
#     Found existing installation: keras 2.9.0
#     Uninstalling keras-2.9.0:
#       Successfully uninstalled keras-2.9.0
#   Attempting uninstall: onnx
#     Found existing installation: onnx 1.13.0
#     Uninstalling onnx-1.13.0:
#       Successfully uninstalled onnx-1.13.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.9.2
#     Uninstalling tensorflow-2.9.2:
#       Successfully uninstalled tensorflow-2.9.2
# Successfully installed flatbuffers-23.1.4 keras-2.11.0 onnx-1.12.0 protobuf-3.19.6 pynini-2.1.5 tensorflow-2.11.0 tensorflow-estimator-2.11.0

# %%
import os
if not os.path.exists("scripts/process_asr_text_tokenizer.py"):
  # !wget -P scripts/ https://raw.githubusercontent.com/NVIDIA/NeMo/$BRANCH/scripts/tokenizers/process_asr_text_tokenizer.py
# Out:
# --2023-01-11 05:51:56--  https://raw.githubusercontent.com/NVIDIA/NeMo/main/scripts/tokenizers/process_asr_text_tokenizer.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13860 (14K) [text/plain]
# Saving to: ‘scripts/process_asr_text_tokenizer.py’
#
# process_asr_text_to 100%[===================>]  13.54K  --.-KB/s    in 0s
#
# 2023-01-11 05:51:56 (41.5 MB/s) - ‘scripts/process_asr_text_tokenizer.py’ saved [13860/13860]

# %%
LANGUAGE = "tr"
tokenizer_dir = os.path.join('tokenizers', LANGUAGE)

# %%
# Manifest Utils
from tqdm.auto import tqdm
import json

def read_manifest(path):
    manifest = []
    with open(path, 'r') as f:
        for line in tqdm(f, desc="Reading manifest data"):
            line = line.replace("\n", "")
            data = json.loads(line)
            manifest.append(data)
    return manifest

from collections import defaultdict

def get_charset(manifest_data):
    charset = defaultdict(int)
    for row in tqdm(manifest_data, desc="Computing character set"):
        text = row['text']
        for character in text:
            charset[character] += 1
    return charset

# %%
train_manifest = "scripts/manifest_100522.jsonl"
train_manifest_data = read_manifest(train_manifest)
train_charset = get_charset(train_manifest_data)
train_set = set(train_charset.keys())
# Out:
# Reading manifest data: 0it [00:00, ?it/s]
# Computing character set:   0%|          | 0/32531 [00:00<?, ?it/s]

# %%
# << VOCAB SIZE can be changed to any value larger than (len(train_dev_set) + 2)! >>
VOCAB_SIZE = len(train_set) + 2
VOCAB_SIZE
# Out:
# 36

# %%
#@title Tokenizer Config { display-mode: "form" }
TOKENIZER_TYPE = "unigram" #@param ["bpe", "unigram"]

# %%
# !python scripts/process_asr_text_tokenizer.py \
  --manifest=$train_manifest \
  --vocab_size=$VOCAB_SIZE \
  --data_root=$tokenizer_dir \
  --tokenizer="spe" \
  --spe_type=$TOKENIZER_TYPE \
  --spe_character_coverage=1.0 \
  --no_lower_case \
  --log
# Out:
# [NeMo W 2023-01-11 05:56:33 optimizers:55] Apex was not found. Using the lamb or fused_adam optimizer will error out.
# INFO:root:Finished extracting manifest : scripts/manifest_100522.jsonl
# INFO:root:Finished extracting all manifests ! Number of sentences : 32531
# [NeMo I 2023-01-11 05:56:34 sentencepiece_tokenizer:315] Processing tokenizers/tr/text_corpus/document.txt and store at tokenizers/tr/tokenizer_spe_unigram_v36
# sentencepiece_trainer.cc(177) LOG(INFO) Running command: --input=tokenizers/tr/text_corpus/document.txt --model_prefix=tokenizers/tr/tokenizer_spe_unigram_v36/tokenizer --vocab_size=36 --shuffle_input_sentence=true --hard_vocab_limit=false --model_type=unigram --character_coverage=1.0 --bos_id=-1 --eos_id=-1
# sentencepiece_trainer.cc(77) LOG(INFO) Starts training with :
# trainer_spec {
#   input: tokenizers/tr/text_corpus/document.txt
#   input_format:
#   model_prefix: tokenizers/tr/tokenizer_spe_unigram_v36/tokenizer
#   model_type: UNIGRAM
#   vocab_size: 36
#   self_test_sample_size: 0
#   character_coverage: 1
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   hard_vocab_limit: 0
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: -1
#   eos_id: -1
#   pad_id: -1
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(350) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(181) LOG(INFO) Loading corpus: tokenizers/tr/text_corpus/document.txt
# trainer_interface.cc(406) LOG(INFO) Loaded all 32531 sentences
# trainer_interface.cc(422) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(427) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(536) LOG(INFO) all chars count=808011
# trainer_interface.cc(557) LOG(INFO) Alphabet size=34
# trainer_interface.cc(558) LOG(INFO) Final character coverage=1
# trainer_interface.cc(590) LOG(INFO) Done! preprocessed 32531 sentences.
# unigram_model_trainer.cc(146) LOG(INFO) Making suffix array...
# unigram_model_trainer.cc(150) LOG(INFO) Extracting frequent sub strings...
# unigram_model_trainer.cc(201) LOG(INFO) Initialized 45117 seed sentencepieces
# trainer_interface.cc(596) LOG(INFO) Tokenizing input sentences with whitespace: 32531
# trainer_interface.cc(607) LOG(INFO) Done! 19752
# unigram_model_trainer.cc(491) LOG(INFO) Using 19752 sentences for EM training
# unigram_model_trainer.cc(507) LOG(INFO) EM sub_iter=0 size=14530 obj=11.3013 num_tokens=34130 num_tokens/piece=2.34893
# unigram_model_trainer.cc(507) LOG(INFO) EM sub_iter=1 size=12004 obj=9.65465 num_tokens=34309 num_tokens/piece=2.85813
# unigram_model_trainer.cc(507) LOG(INFO) EM sub_iter=0 size=8997 obj=9.65127 num_tokens=36542 num_tokens/piece=4.06158
# unigram_model_trainer.cc(507) LOG(INFO) EM sub_iter=1 size=8974 obj=9.58905 num_tokens=36550 num_tokens/piece=4.07288
# unigram_model_trainer.cc(507) LOG(INFO) EM sub_iter=0 size=6730 obj=9.77416 num_tokens=40038 num_tokens/piece=5.94918
# unigram_model_trainer.cc(507) LOG(INFO) EM sub_iter=1 size=6730 obj=9.7201 num_tokens=40032 num_tokens/piece=5.94829
# unigram_model_trainer.cc(507) LOG(INFO) EM sub_iter=0 size=5047 obj=9.97905 num_tokens=43830 num_tokens/piece=8.68437
# unigram_model_trainer.cc(507) LOG(INFO) EM sub_iter=1 size=5047 obj=9.9147 num_tokens=43824 num_tokens/piece=8.68318
# unigram_model_trainer.cc(507) LOG(INFO) EM sub_iter=0 size=3785 obj=10.2397 num_tokens=48126 num_tokens/piece=12.7149
# unigram_model_trainer.cc(507) LOG(INFO) EM sub_iter=1 size=3785 obj=10.1685 num_tokens=48129 num_tokens/piece=12.7157
# unigram_model_trainer.cc(507) LOG(INFO) EM sub_iter=0 size=2838 obj=10.5576 num_tokens=52772 num_tokens/piece=18.5948
# unigram_model_trainer.cc(507) LOG(INFO) EM sub_iter=1 size=2838 obj=10.4739 num_tokens=52772 num_tokens/piece=18.5948
# unigram_model_trainer.cc(507) LOG(INFO) EM sub_iter=0 size=2128 obj=10.9404 num_tokens=57775 num_tokens/piece=27.1499
# unigram_model_trainer.cc(507) LOG(INFO) EM sub_iter=1 size=2128 obj=10.8419 num_tokens=57780 num_tokens/piece=27.1523
# unigram_model_trainer.cc(507) LOG(INFO) EM sub_iter=0 size=1596 obj=11.3788 num_tokens=63204 num_tokens/piece=39.6015
# unigram_model_trainer.cc(507) LOG(INFO) EM sub_iter=1 size=1596 obj=11.2676 num_tokens=63206 num_tokens/piece=39.6028
# unigram_model_trainer.cc(507) LOG(INFO) EM sub_iter=0 size=1197 obj=11.92 num_tokens=68632 num_tokens/piece=57.3367
# unigram_model_trainer.cc(507) LOG(INFO) EM sub_iter=1 size=1197 obj=11.7942 num_tokens=68633 num_tokens/piece=57.3375
# unigram_model_trainer.cc(507) LOG(INFO) EM sub_iter=0 size=897 obj=12.4892 num_tokens=74681 num_tokens/piece=83.2564
# unigram_model_trainer.cc(507) LOG(INFO) EM sub_iter=1 size=897 obj=12.3453 num_tokens=74676 num_tokens/piece=83.2508
# unigram_model_trainer.cc(507) LOG(INFO) EM sub_iter=0 size=672 obj=13.1242 num_tokens=79829 num_tokens/piece=118.793
# unigram_model_trainer.cc(507) LOG(INFO) EM sub_iter=1 size=672 obj=12.9779 num_tokens=79829 num_tokens/piece=118.793
# unigram_model_trainer.cc(507) LOG(INFO) EM sub_iter=0 size=504 obj=13.8255 num_tokens=84879 num_tokens/piece=168.411
# unigram_model_trainer.cc(507) LOG(INFO) EM sub_iter=1 size=504 obj=13.6518 num_tokens=84879 num_tokens/piece=168.411
# unigram_model_trainer.cc(507) LOG(INFO) EM sub_iter=0 size=378 obj=14.5536 num_tokens=91229 num_tokens/piece=241.347
# unigram_model_trainer.cc(507) LOG(INFO) EM sub_iter=1 size=378 obj=14.3375 num_tokens=91236 num_tokens/piece=241.365
# unigram_model_trainer.cc(507) LOG(INFO) EM sub_iter=0 size=283 obj=15.4053 num_tokens=98413 num_tokens/piece=347.749
# unigram_model_trainer.cc(507) LOG(INFO) EM sub_iter=1 size=283 obj=15.1496 num_tokens=98423 num_tokens/piece=347.784
# unigram_model_trainer.cc(507) LOG(INFO) EM sub_iter=0 size=212 obj=16.2585 num_tokens=104656 num_tokens/piece=493.66
# unigram_model_trainer.cc(507) LOG(INFO) EM sub_iter=1 size=212 obj=16.0069 num_tokens=104648 num_tokens/piece=493.623
# unigram_model_trainer.cc(507) LOG(INFO) EM sub_iter=0 size=159 obj=17.2974 num_tokens=111580 num_tokens/piece=701.761
# unigram_model_trainer.cc(507) LOG(INFO) EM sub_iter=1 size=159 obj=17.0304 num_tokens=111616 num_tokens/piece=701.987
# unigram_model_trainer.cc(507) LOG(INFO) EM sub_iter=0 size=119 obj=18.1542 num_tokens=122620 num_tokens/piece=1030.42
# unigram_model_trainer.cc(507) LOG(INFO) EM sub_iter=1 size=119 obj=17.834 num_tokens=122620 num_tokens/piece=1030.42
# unigram_model_trainer.cc(507) LOG(INFO) EM sub_iter=0 size=89 obj=19.0064 num_tokens=131632 num_tokens/piece=1479.01
# unigram_model_trainer.cc(507) LOG(INFO) EM sub_iter=1 size=89 obj=18.5959 num_tokens=132406 num_tokens/piece=1487.71
# unigram_model_trainer.cc(507) LOG(INFO) EM sub_iter=0 size=66 obj=19.7405 num_tokens=142585 num_tokens/piece=2160.38
# unigram_model_trainer.cc(507) LOG(INFO) EM sub_iter=1 size=66 obj=19.2375 num_tokens=142585 num_tokens/piece=2160.38
# unigram_model_trainer.cc(507) LOG(INFO) EM sub_iter=0 size=49 obj=20.4721 num_tokens=155899 num_tokens/piece=3181.61
# unigram_model_trainer.cc(507) LOG(INFO) EM sub_iter=1 size=49 obj=19.97 num_tokens=155899 num_tokens/piece=3181.61
# unigram_model_trainer.cc(507) LOG(INFO) EM sub_iter=0 size=39 obj=20.8815 num_tokens=166911 num_tokens/piece=4279.77
# unigram_model_trainer.cc(507) LOG(INFO) EM sub_iter=1 size=39 obj=20.4689 num_tokens=166911 num_tokens/piece=4279.77
# trainer_interface.cc(685) LOG(INFO) Saving model: tokenizers/tr/tokenizer_spe_unigram_v36/tokenizer.model
# trainer_interface.cc(697) LOG(INFO) Saving vocabs: tokenizers/tr/tokenizer_spe_unigram_v36/tokenizer.vocab
# Serialized tokenizer at location : tokenizers/tr/tokenizer_spe_unigram_v36
# INFO:root:Done!

# %%
TOKENIZER_DIR = f"{tokenizer_dir}/tokenizer_spe_{TOKENIZER_TYPE}_v{VOCAB_SIZE}/"
print("Tokenizer directory :", TOKENIZER_DIR)
# Out:
# Tokenizer directory : tokenizers/tr/tokenizer_spe_unigram_v36/

# %%
# Number of tokens in tokenizer - 
with open(os.path.join(TOKENIZER_DIR, 'tokenizer.vocab')) as f:
  tokens = f.readlines()

num_tokens = len(tokens)
print("Number of tokens : ", num_tokens)
# Out:
# Number of tokens :  36

# %%
if num_tokens < VOCAB_SIZE:
    print(
        f"The text in this dataset is too small to construct a tokenizer "
        f"with vocab size = {VOCAB_SIZE}. Current number of tokens = {num_tokens}. "
        f"Please reconstruct the tokenizer with fewer tokens"
    )

# %%
# !zip -r tokenizers.zip /content/tokenizers
# Out:
#   adding: content/tokenizers/ (stored 0%)
#   adding: content/tokenizers/tr/ (stored 0%)
#   adding: content/tokenizers/tr/tokenizer_spe_unigram_v36/ (stored 0%)
#   adding: content/tokenizers/tr/tokenizer_spe_unigram_v36/tokenizer.model (deflated 42%)
#   adding: content/tokenizers/tr/tokenizer_spe_unigram_v36/tokenizer.vocab (deflated 40%)
#   adding: content/tokenizers/tr/tokenizer_spe_unigram_v36/vocab.txt (deflated 40%)
#   adding: content/tokenizers/tr/text_corpus/ (stored 0%)
#   adding: content/tokenizers/tr/text_corpus/document.txt (deflated 66%)

# %%
from google.colab import files
files.download('tokenizers.zip')

# %% [markdown]
# Training

# %%
import os
if not os.path.exists("configs/config_bpe.yaml"):
  # !wget -P configs/ https://raw.githubusercontent.com/NVIDIA/NeMo/$BRANCH/examples/asr/conf/citrinet/config_bpe.yaml
# Out:
# --2023-01-11 05:56:47--  https://raw.githubusercontent.com/NVIDIA/NeMo/main/examples/asr/conf/citrinet/config_bpe.yaml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4375 (4.3K) [text/plain]
# Saving to: ‘configs/config_bpe.yaml’
#
# config_bpe.yaml     100%[===================>]   4.27K  --.-KB/s    in 0s
#
# 2023-01-11 05:56:47 (47.3 MB/s) - ‘configs/config_bpe.yaml’ saved [4375/4375]

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Getting the subwords of the transcript or tokenizing a dataset using the same tokenizer as the ASR model.

# %%
import nemo.collections.asr as nemo_asr
from ruamel.yaml import YAML
import pytorch_lightning as pl
from omegaconf import DictConfig, OmegaConf, open_dict
import copy
from pytorch_lightning.loggers import WandbLogger
from pytorch_lightning.callbacks import ModelCheckpoint
import os

config_path = "configs/config_bpe.yaml"

yaml = YAML(typ='safe')
with open(config_path) as f:
    params = yaml.load(f)

params['model']['train_ds']['manifest_filepath'] = "scripts/manifest_100522.jsonl"
params['model']['validation_ds']['manifest_filepath'] = "scripts/manifest_100522.jsonl"

params['model']['tokenizer']['dir'] = TOKENIZER_DIR
params['model']['tokenizer']['type'] = 'bpe'

first_asr_model = nemo_asr.models.EncDecCTCModelBPE(cfg=DictConfig(params['model']))
first_asr_model.change_vocabulary(new_tokenizer_dir=TOKENIZER_DIR, new_tokenizer_type="bpe")

tokenizer = first_asr_model.tokenizer
print("tokenizer:",tokenizer)
tokens = tokenizer.text_to_tokens("merhaba nasılsın")
print("tokens:",tokens)
token_ids = tokenizer.text_to_ids("merhaba nasılsın")
print("token_ids:",token_ids)
subwords = tokenizer.ids_to_tokens(token_ids)
print("subwords:",subwords)
text = tokenizer.ids_to_text(token_ids)
print("text:",text)
# Out:
# [NeMo I 2023-01-11 08:19:51 mixins:170] Tokenizer SentencePieceTokenizer initialized with 36 tokens
# [NeMo I 2023-01-11 08:19:51 ctc_bpe_models:64]
#     Replacing placeholder number of classes (-1) with actual number of classes - 36
# [NeMo I 2023-01-11 08:19:53 collections:193] Dataset loaded with 32531 files totalling 27.57 hours
# [NeMo I 2023-01-11 08:19:53 collections:194] 0 files were filtered totalling 0.00 hours
# [NeMo I 2023-01-11 08:19:55 collections:193] Dataset loaded with 32531 files totalling 27.57 hours
# [NeMo I 2023-01-11 08:19:55 collections:194] 0 files were filtered totalling 0.00 hours
# [NeMo I 2023-01-11 08:19:55 features:267] PADDING: 16
# [NeMo W 2023-01-11 08:19:55 modelPT:236] You tried to register an artifact under config key=tokenizer.model_path but an artifact for it has already been registered.
# [NeMo W 2023-01-11 08:19:55 modelPT:236] You tried to register an artifact under config key=tokenizer.vocab_path but an artifact for it has already been registered.
# [NeMo W 2023-01-11 08:19:55 modelPT:236] You tried to register an artifact under config key=tokenizer.spe_tokenizer_vocab but an artifact for it has already been registered.
# [NeMo I 2023-01-11 08:19:55 mixins:170] Tokenizer SentencePieceTokenizer initialized with 36 tokens
# [NeMo I 2023-01-11 08:19:55 ctc_bpe_models:296]
#     Replacing old number of classes (36) with new number of classes - 36
# [NeMo I 2023-01-11 08:19:55 ctc_bpe_models:338] Changed tokenizer to ['<unk>', '▁', 'a', 'e', 'i', 'n', 'l', 'ı', 'k', 'r', 'm', 't', 'u', 'd', 'y', 's', 'b', 'o', 'z', 'ü', 'ş', 'ar', 'g', 'ç', 'h', 'v', 'p', 'c', 'f', 'ö', 'j', 'w', 'q', '̇', 'x', 'ğ'] vocabulary.
# tokenizer: <nemo.collections.common.tokenizers.sentencepiece_tokenizer.SentencePieceTokenizer object at 0x7f5d2ee7bf10>
# tokens: ['▁', 'm', 'e', 'r', 'h', 'a', 'b', 'a', '▁', 'n', 'a', 's', 'ı', 'l', 's', 'ı', 'n']
# token_ids: [1, 10, 3, 9, 24, 2, 16, 2, 1, 5, 2, 15, 7, 6, 15, 7, 5]
# subwords: ['▁', 'm', 'e', 'r', 'h', 'a', 'b', 'a', '▁', 'n', 'a', 's', 'ı', 'l', 's', 'ı', 'n']
# text: merhaba nasılsın

# %%
def training():

    N_GPUS = 1
    N_DEVICES = 1
    EPOCHS = 10
   
    config_path = "configs/config_bpe.yaml"

    yaml = YAML(typ='safe')
    with open(config_path) as f:
        params = yaml.load(f)

    params['model']['train_ds']['manifest_filepath'] = "scripts/manifest_100522.jsonl"
    params['model']['validation_ds']['manifest_filepath'] = "scripts/manifest_100522.jsonl"

    params['model']['train_ds']['batch_size'] = 32 * N_GPUS * N_DEVICES

    params['model']['tokenizer']['dir'] = TOKENIZER_DIR
    params['model']['tokenizer']['type'] = 'bpe'

    # model_to_load = "epoch-99.ckpt"

    first_asr_model = nemo_asr.models.EncDecCTCModelBPE(cfg=DictConfig(params['model']))

    # first_asr_model = first_asr_model.load_from_checkpoint(model_to_load)

    new_opt = copy.deepcopy(params['model']['optim'])

    new_opt['lr'] = 0.001
    # Point to the data we'll use for fine-tuning as the training set
    first_asr_model.setup_training_data(train_data_config=params['model']['train_ds'])
    # Point to the new validation data for fine-tuning
    first_asr_model.setup_validation_data(val_data_config=params['model']['validation_ds'])
    # assign optimizer config
    first_asr_model.setup_optimization(optim_config=DictConfig(new_opt))

    first_asr_model.change_vocabulary(new_tokenizer_dir=TOKENIZER_DIR, new_tokenizer_type="bpe")

    wandb_logger = WandbLogger(name="Citrinet", project="TURKISH_FINETUNING")
    # used for saving models
    save_path = os.path.join(os.getcwd(),"TURKISH_FINETUNING" + "_" + "Citrinet_models")
    checkpoint_callback = ModelCheckpoint(
        dirpath=save_path,
        save_top_k= -1,
        verbose=True,
        monitor='val_loss',
        mode='min',
    )

    trainer = pl.Trainer(devices=N_GPUS, accelerator='cpu',num_nodes=N_DEVICES,  # accelerator='ddp'
                  max_epochs=EPOCHS,
                  logger=wandb_logger, log_every_n_steps=1,
                  val_check_interval=1.0, enable_checkpointing=checkpoint_callback)

    first_asr_model.set_trainer(trainer)

    trainer.fit(first_asr_model)

if __name__ == '__main__':
    training()
